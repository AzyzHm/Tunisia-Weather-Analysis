# %% [markdown]
# # Analyse météo tunisienne

# %% [markdown]
# ## Introduction:

# %% [markdown]
# Dans le cadre de notre projet, nous allons examiner les données météorologiques tunisiennes couvrant la période de 1983 à 2023 afin de mieux comprendre les divers facteurs qui influencent le comportement de la météo.
#
# Ce projet englobe l'analyse de la température, du vent et des précipitations, dans le but ultime de prédire les valeurs de température pour les années à venir.
#
# > <span style="color:magenta">Travail realisé par : Ghofrane saadallah & Mohammed Aziz Hammemi</span>

# %% [markdown]
# ## Chargement des données:

# %%
# importer les librairies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Supprimer les valeurs manquantes (dans notre cas on a pas de valeurs manquantes)
cleaned_data = data.dropna()

# %%
# Rechercher les lignes en double
duplicate_rows = cleaned_data.duplicated().sum()
print(f"nombre des lignes en double: {duplicate_rows}")
# Out:
# nombre des lignes en double: 0

# %%
# Supprimer les lignes en double (dans notre cas on a pas aussi de lignes en double)
cleaned_data = cleaned_data.drop_duplicates()

# %%
# Check data types of columns
print(cleaned_data.dtypes)
# Out:
# YEAR             int64
# MO               int64
# DY               int64
# T2M            float64
# T2MDEW         float64
# T2M_MAX        float64
# T2M_MIN        float64
# TS             float64
# WS10M          float64
# WD10M          float64
# WS50M          float64
# WD50M          float64
# PS             float64
# PRECTOTCORR    float64
# RH2M           float64
# dtype: object

# %%
mydata.columns
# Out:
# Index(['Année', 'Mois', 'Jour', 'Température_2m',
#        'Point_de_Rosée_Température_2m', 'Température_2m_Max',
#        'Température_2m_Min', 'Température_Surface', 'Vitesse_Vent_10m',
#        'Direction_Vent_10m', 'Vitesse_Vent_50m', 'Direction_Vent_50m',
#        'Pression_Surface', 'Précipitation_Totale_Corrigée',
#        'Humidité_Relative_2m'],
#       dtype='object')

# %% [markdown]
# ## Visualisation des données:

# %% [markdown]
# ### Etude des Températures:

# %% [markdown]
# #### Variation Annuelle

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='Année', y='Température_2m', data=mydata, marker='o', linestyle='-')
plt.xlabel('Année')
plt.ylabel('Température (°C)')
plt.title('Variation de la Température Moyenne au Fil des Années')
plt.grid(True)
plt.show()

# %% [markdown]
# - Ce graphique présente les fluctuations de la moyenne des températures maximales, moyennes et minimales au fil du temps.
#
# - Il est intéressant de noter que la température maximale a connu une tendance à la hausse depuis 1983, passant d'environ 19°C à près de 20°C en 1994, où elle est restée relativement stable jusqu'en 2004 avant de connaître une légère baisse à environ 19°C. Elle a ensuite suivi un cycle similaire jusqu'en 2016. Depuis 2016, sa valeur a augmenté pour atteindre un pic en 2022, approchant les 30°C.
#
# - Les températures moyenne et minimale ont eu le même rythme où leurs valeurs respectives en 1983 étaient 18°C et prés de 17°C,  ont dépassées les 18°C et 19°C en 1994 pour chuter en 2004 avec des valeurs inférieures à 18°C et 17°C puis progressent jusqu'à 2016 pour atteindre les 20°C et 19°C en 2022.

# %% [markdown]
# #### Variation Saisonniére:

# %%
# Copier les données originales pour ne pas les modifier
season_data = mydata.copy()

# Définir les saisons en fonction des mois
season_data['Saison'] = 'Hiver'
season_data.loc[(season_data['Mois'] >= 3) & (season_data['Mois'] <= 5), 'Saison'] = 'Printemps'
season_data.loc[(season_data['Mois'] >= 6) & (season_data['Mois'] <= 8), 'Saison'] = 'Été'
season_data.loc[(season_data['Mois'] >= 9) & (season_data['Mois'] <= 11), 'Saison'] = 'Automne'

# Calculer les statistiques saisonnières
seasonal_stats = season_data.groupby('Saison').agg({
    'Température_2m': ['mean', 'min', 'max'],
    'Vitesse_Vent_10m': ['mean', 'min', 'max'],
    'Précipitation_Totale_Corrigée': ['mean', 'sum']
})
print(seasonal_stats)
# Out:
#           Température_2m               Vitesse_Vent_10m               \
#                     mean    min    max             mean   min    max
# Saison
# Automne        19.414453   4.83  32.50         3.596464  1.08  13.20
# Hiver           9.249425   1.46  20.59         4.260180  1.15  14.61
# Printemps      16.654202   3.80  32.56         4.128818  1.04  13.88
# Été            27.973819  15.13  37.18         3.446408  1.07  11.03
#
#           Précipitation_Totale_Corrigée
#                                    mean      sum
# Saison
# Automne                        1.110956  4043.88
# Hiver                          0.957424  3512.79
# Printemps                      1.113375  4199.65
# Été                            0.534500  2000.10

# %% [markdown]
# - Tout d'abord, il est clair que la température moyenne varie considérablement d'une saison à l'autre, avec des pointes atteignant 37.18°C pendant l'été et des baisses à 1.46°C pendant l'hiver. Cette variation témoigne des saisons distinctes que connaît le pays, avec des contrastes marqués entre les mois chauds et froids.
#
# - Parallèlement, la radiation solaire descendante suit également un schéma saisonnier, avec des niveaux plus élevés en été et en automne, suggérant une plus grande exposition au soleil pendant ces saisons.
#
# - En ce qui concerne la vitesse du vent, bien qu'elle reste relativement stable tout au long de l'année, des valeurs légèrement plus élevées sont observées pendant l'hiver.
#
# - Enfin, les précipitations totales corrigées montrent une certaine variabilité saisonnière, avec des moyennes annuelles les plus élevées en automne, suivies de près par le printemps.

# %%
# Graphique de variation saisonnière de la Température_2m
plt.figure(figsize=(12, 6))
sns.boxplot(x='Saison', y='Température_2m', data=season_data, order=['Hiver', 'Printemps', 'Été', 'Automne'])
plt.xlabel('Saison')
plt.ylabel('Température (°C)')
plt.title('Variation de la Température Moyenne par Saison')
plt.grid(True)
plt.show()

# %% [markdown]
# - Cette boite a mustache repésente **la variation de la temperature moyenne par saison** , voici un résumé des données:
#     - **Hiver**: Les températures varient approximativement de 5 à 15°C, avec un point aberrant proche de 30°C.
#     - **Printemps**: Les températures sont réparties entre environ 15 à 25°C, avec un point aberrant proche de 0°C.
#     - **Été**: Les températures sont concentrées autour de 25 à 30°C.
#     - **Automne**: Les températures varient entre environ 10 à presque 30°C, avec un point aberrant proche de 0°C.

# %% [markdown]
# #### Variation des températures annuelles min, moyenne et max:

# %%
# Graphique de variation temporelle de la Température_2m
plt.figure(figsize=(12, 6))
sns.lineplot(x='Année', y='Température_2m', data=mydata, marker='o', label='Température 2m')
sns.lineplot(x='Année', y='Température_2m_Max', data=mydata, marker='o', label='Température 2m Max')
sns.lineplot(x='Année', y='Température_2m_Min', data=mydata, marker='o', label='Température 2m Min')
plt.xlabel('Année')
plt.ylabel('Température (°C)')
plt.title('Variation Temporelle des Températures')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# - ce graphique représente **la variation des températures au fil des années en tunisie**. Voici un résumé des données :
#     - **Température 2m (Mean Temperature)** : La ligne bleue oscille entre environ 17,5°C et 22,5°C, représentant la température moyenne mesurée à 2 mètres au-dessus du niveau du sol.
#     - **Température 2m Max (Max Temperature)** : La ligne orange oscille entre environ 22,5°C et juste au-dessus de 27,5°C, indiquant les températures maximales enregistrées.
#     - **Température 2m Min (Min Temperature)** : La ligne verte oscille entre environ 10°C et légèrement au-dessus de 15°C, indiquant les températures minimales enregistrées.

# %% [markdown]
# #### Variation Mensuelle des Températures:

# %%
# Calculer les températures mensuelles moyennes, maximales et minimales
monthly_temps = mydata.groupby('Mois').agg({
    'Température_2m': 'mean',
    'Température_2m_Max': 'mean',
    'Température_2m_Min': 'mean'
})

# Graphique de variation mensuelle des Températures
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_temps.index, y='Température_2m', data=monthly_temps, marker='o', label='Température 2m Moyenne')
sns.lineplot(x=monthly_temps.index, y='Température_2m_Max', data=monthly_temps, marker='o', label='Température 2m Max Moyenne')
sns.lineplot(x=monthly_temps.index, y='Température_2m_Min', data=monthly_temps, marker='o', label='Température 2m Min Moyenne')
plt.xlabel('Mois')
plt.ylabel('Température (°C)')
plt.title('Variation Mensuelle des Températures Moyennes')
plt.xticks(ticks=monthly_temps.index, labels=['Jan', 'Fév', 'Mar', 'Avr', 'Mai', 'Juin', 'Juil', 'Août', 'Sep', 'Oct', 'Nov', 'Déc'])
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# > L'objectif de ce graphique n'est pas d'analyser les variations mensuelles de la température, car celles-ci sont souvent naturelles et prévisibles. Au contraire, il vise à illustrer que même pendant les mois traditionnellement chauds, comme août et juin, la température peut parfois chuter à des niveaux considérés comme anormalement bas, comme 21°C en juin, ou à des niveaux de chaleur extrême approchant les 40°C. De même, pendant l'hiver, le mois de janvier peut enregistrer des températures inférieures à 5°C, ce qui peut être inhabituel.

# %% [markdown]
# ### Analyse des Événements Météorologiques Extrêmes :

# %%
# Identifier les événements météorologiques extrêmes (par exemple, vagues de chaleur)
heatwaves = mydata[mydata['Température_2m_Max'] > 35]  # Définir un seuil de température pour les vagues de chaleur

# Afficher les années et les mois des vagues de chaleur
print("Années et Mois des Vagues de Chaleur :")
print(heatwaves[['Année', 'Mois']].drop_duplicates().sort_values(by=['Année', 'Mois']))

#Distribution des Températures Maximales pendant les Vagues de Chaleur
plt.figure(figsize=(12, 6))
sns.histplot(data=heatwaves, x='Température_2m_Max', bins=30, color='yellow')
plt.xlabel('Température (°C)')
plt.title('Distribution des Températures Maximales pendant les Vagues de Chaleur')
plt.grid(True)
plt.show()

# Calculate the number of heatwaves per year
heatwaves_per_year = heatwaves.groupby('Année').size()

# Plot the number of heatwaves per year
plt.figure(figsize=(12, 6))
sns.lineplot(x=heatwaves_per_year.index, y=heatwaves_per_year.values, marker='o' , color='red')
plt.xlabel('Année')
plt.ylabel('Nombre de Vagues de Chaleur')
plt.title('Nombre de Vagues de Chaleur par Année')
plt.grid(True)
plt.show()
# Out:
# Années et Mois des Vagues de Chaleur :
#        Année  Mois
# 157     1983     6
# 181     1983     7
# 212     1983     8
# 243     1983     9
# 512     1984     5
# ...      ...   ...
# 14488   2022     9
# 14728   2023     4
# 14778   2023     6
# 14791   2023     7
# 14822   2023     8
#
# [193 rows x 2 columns]

# %% [markdown]
# - À partir du 1er graphique, il est observé que le nombre de vagues de chaleur les plus significatives se situe entre 35°C et 38°C, avec une valeur cumulée d'environ 1262 vagues. Cependant, il est à noter qu'il peut y avoir des vagues de chaleur atteignant jusqu'à 46°C, bien que ces occurrences soient rares.
#
# - D'après le 2e graphique, on observe que les années 1983 à 1991 ont connu entre 50 et 71 vagues de chaleur. En 1992, le nombre de vagues de chaleur a atteint un minimum, tombant en dessous de 30 vagues. Entre 1994 et 2020, le nombre de vagues varie principalement entre 50 et 84, avec un pic en 2022 où l'on compte environ 110 vagues de chaleur.

# %% [markdown]
# ### Analyse du Vent :

# %% [markdown]
# #### Variation Temporelle de la Vitesse du Vent :

# %%
# Graphique de variation temporelle de la Vitesse_Vent_10m(moyenne)
plt.figure(figsize=(12, 6))
sns.lineplot(x='Année', y='Vitesse_Vent_10m', data=mydata, marker='o', color='blue')
plt.xlabel('Année')
plt.ylabel('Vitesse du Vent (m/s)')
plt.title('Variation Temporelle de la Vitesse du Vent')
plt.grid(True)
plt.show()

# %% [markdown]
# - Ce graphique met en évidence les variations de la vitesse du vent, avec une moyenne oscillant entre 3,6 m/s et 4 m/s. Cependant, il est observé que cet intervalle a changé à partir des années 2010, où il a fluctué entre un minimum de 3,8 m/s et un maximum de 4,2 m/s.
#
# - Il est également remarquable que les années 1989 et 1999 se distinguent, car le minimum de la vitesse du vent a atteint 3,4 m/s, tandis qu'en 2019, le maximum de la vitesse du vent a atteint un pic de 4,4 m/s.

# %% [markdown]
# #### Variation Mensuelle de la Vitesse du Vent :

# %%
# Calculer les vitesses du vent mensuelles moyennes
monthly_wind = mydata.groupby('Mois').agg({
    'Vitesse_Vent_10m': 'mean'
})

# Graphique de variation mensuelle de la Vitesse du Vent
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_wind.index, y='Vitesse_Vent_10m', data=monthly_wind, marker='o', color='green')
plt.xlabel('Mois')
plt.ylabel('Vitesse du Vent (m/s)')
plt.title('Variation Mensuelle de la Vitesse du Vent Moyenne')
plt.xticks(ticks=monthly_wind.index, labels=['Jan', 'Fév', 'Mar', 'Avr', 'Mai', 'Juin', 'Juil', 'Août', 'Sep', 'Oct', 'Nov', 'Déc'])
plt.grid(True)
plt.show()

# %% [markdown]
# - Ce graphique met en évidence la variation mensuelle de la vitesse moyenne du vent. En effet, en janvier, la vitesse du vent est la plus élevée, dépassant légèrement les 4 m/s. En revanche, en juillet, elle est au plus bas, descendant à environ 3,2 m/s. Enfin, en décembre, la vitesse du vent augmente à nouveau, approchant les valeurs de janvier.

# %% [markdown]
# ###

# %% [markdown]
# ### Analyse de la Pression Atmosphérique et de la Précipitation :

# %% [markdown]
# #### Variation Temporelle de la Pression Atmosphérique :

# %%
# Graphique de variation temporelle de la Pression_Surface(moyenne)
plt.figure(figsize=(12, 6))
sns.lineplot(x='Année', y='Pression_Surface', data=mydata, marker='o', color='purple')
plt.xlabel('Année')
plt.ylabel('Pression Atmosphérique (hPa)')
plt.title('Variation Temporelle de la Pression Atmosphérique')
plt.grid(True)
plt.show()

# %% [markdown]
# >La pression atmosphérique est le paramètre qui présente la plus grande variation dans notre étude. En effet, sa moyenne varie de 96,85 hPa à 97,02 hPa de 1983 à 2008, avec une chute à 96,77 hPa en 1996. En 2010, on observe une baisse considérable à 96,68 hPa, suivie d'une augmentation pour se maintenir entre 96,82 hPa et 97,05 hPa par la suite.

# %% [markdown]
# #### Variation Mensuelle de la Pression Atmosphérique :

# %%
# Calculer les pressions atmosphériques mensuelles moyennes
monthly_pressure = mydata.groupby('Mois').agg({
    'Pression_Surface': 'mean'
})

# Graphique de variation mensuelle de la Pression Atmosphérique
plt.figure(figsize=(12, 6))
sns.lineplot(x=monthly_pressure.index, y='Pression_Surface', data=monthly_pressure, marker='o', color='blue')
plt.xlabel('Mois')
plt.ylabel('Pression Atmosphérique (hPa)')
plt.title('Variation Mensuelle de la Pression Atmosphérique Moyenne')
plt.xticks(ticks=monthly_pressure.index, labels=['Jan', 'Fév', 'Mar', 'Avr', 'Mai', 'Juin', 'Juil', 'Août', 'Sep', 'Oct', 'Nov', 'Déc'])
plt.grid(True)
plt.show()

# %% [markdown]
# >En début d'année, la pression atmosphérique débute à 97,2 hPa, puis elle décroît progressivement jusqu'en avril, où elle atteint un minimum de moins de 96,7 hPa, avant de commencer à augmenter à nouveau. En décembre, sa valeur se rapproche à nouveau de 97,2 hPa.

# %% [markdown]
# #### Variation Temporelle de la Précipitation :

# %%
# Graphique de variation temporelle de la Précipitation_Totale_Corrigée
plt.figure(figsize=(12, 6))
sns.lineplot(x='Année', y='Précipitation_Totale_Corrigée', data=mydata, marker='o', color='green')
plt.xlabel('Année')
plt.ylabel('Précipitation Totale (inches)')
plt.title('Variation Temporelle de la Précipitation Totale')
plt.grid(True)
plt.show()

# %% [markdown]
# >Ce graphique illustre les variations des précipitations moyennes, qui se situent généralement entre 0,6 et 1,6 pouces, à l'exception de deux années spécifiques : 1990, où elles atteignent 2,0 pouces, et 2003, avec 1,6 pouces.

# %% [markdown]
# #### Variation Mensuelle de la Précipitation :

# %%
# Calculer les précipitations mensuelles totales
monthly_precipitation = mydata.groupby('Mois').agg({
    'Précipitation_Totale_Corrigée': 'sum'
})

# Graphique de variation mensuelle de la Précipitation Totale
plt.figure(figsize=(12, 6))
sns.barplot(x=monthly_precipitation.index, y='Précipitation_Totale_Corrigée', data=monthly_precipitation, color='orange')
plt.xlabel('Mois')
plt.ylabel('Précipitation Totale (mm)')
plt.title('Variation Mensuelle de la Précipitation Totale')
plt.xticks(ticks=monthly_precipitation.index, labels=['Jan', 'Fév', 'Mar', 'Avr', 'Mai', 'Juin', 'Juil', 'Août', 'Sep', 'Oct', 'Nov', 'Déc'])
plt.grid(True, axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# >Ce graphique met en évidence les mois présentant des précipitations plus importantes : décembre, février et août, tandis que le mois ayant le moins de précipitations est juin.

# %% [markdown]
# ## Analyse statistique :

# %% [markdown]
# ### Corrélation entre la vitesse de vent et la precipitation

# %%
correlation = mydata['Vitesse_Vent_10m'].corr(mydata['Précipitation_Totale_Corrigée'])
print("Corrélation entre la vitesse du vent et la precipitation:", correlation)

# Calcule de correlation entre la vitesse du vent et la precipitation
correlation = mydata['Vitesse_Vent_10m'].corr(mydata['Précipitation_Totale_Corrigée'])

# creation du plot de correlation entre la vitesse du vent et la precipitation
sns.regplot(data=mydata, x='Vitesse_Vent_10m', y='Précipitation_Totale_Corrigée' ,fit_reg=True,marker='+').set_title('Corrélation entre la vitesse du vent et la precipitation')
# Out:
# Corrélation entre la vitesse du vent et la precipitation: 0.1020261466299438
# Text(0.5, 1.0, 'Corrélation entre la vitesse du vent et la precipitation')

# %% [markdown]
# * <span style="color:cyan">on remarque qu'il existe une corrélation positive faible (0.102) entre la vitesse du vent et la precipitation.</span>

# %% [markdown]
# ### Corrélation entre la temperature et l humidité relative:

# %%
# calcule de correlation
correlation = mydata['Température_2m'].corr(mydata['Humidité_Relative_2m'])
print("Corrélation entre la temperature et l humidité relative:", correlation)

# Creation du plot du correlation entre la temperature et l humidité relative
sns.regplot(data=mydata, x='Température_2m', y='Humidité_Relative_2m',fit_reg=True,marker="+").set_title('Corrélation entre la temperature et l humidité relative')
# Out:
# Corrélation entre la temperature et l humidité relative: -0.7276375547702316
# Text(0.5, 1.0, 'Corrélation entre la temperature et l humidité relative')

# %% [markdown]
# * <span style="color:cyan">on remarque qu'il existe une corrélation négative forte (-0.727) entre la temperature et l'humidité relative.</span>

# %% [markdown]
# ### Correlation entre la vitesse du vent et la direction du vent:

# %%
# Calcule de correlation entre la vitesse du vent et la direction du vent
correlation = mydata['Vitesse_Vent_10m'].corr(mydata['Direction_Vent_10m'])
print("correlation entre la vitesse du vent et la direction du vent:", correlation)

# Creation du plot du correlation entre la vitesse du vent et la direction du vent
sns.regplot(data=mydata, x='Vitesse_Vent_10m', y='Direction_Vent_10m',fit_reg=True,marker="+").set_title('correlation entre la vitesse du vent et la direction du vent')
# Out:
# correlation entre la vitesse du vent et la direction du vent: 0.2501750975449711
# Text(0.5, 1.0, 'correlation entre la vitesse du vent et la direction du vent')

# %% [markdown]
# - <span style="color:cyan">on remarque qu'il existe une corrélation positive faible (0.250) entre la vitesse du vent et la direction du vent.</span>

# %% [markdown]
# ### la matrice de corrélation:

# %%
# Calculer la matrice de corrélation
corr = mydata.corr()

# Générer un masque pour le triangle supérieur
mask = np.triu(np.ones_like(corr, dtype=bool))

# Configurer la figure matplotlib
f, ax = plt.subplots(figsize=(15, 12))

# Générer une palette de couleurs divergente personnalisée
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Dessiner la carte de chaleur avec le masque et le bon rapport d'aspect
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True, annot_kws={"size": 8})

plt.show()

# %% [markdown]
# >Ce graphique met en évidence les valeurs présentant des corrélations fortes et celles ayant des corrélations faibles.

# %% [markdown]
# ## Modèle de Prédiction de Température : Prévision des Tendances Climatiques Futures:

# %%
# 1. Prétraitement
heatwaves['Année'] = heatwaves['Année'].astype(float)

# 2. Sélection des caractéristiques
features = heatwaves[['Année']]
target = heatwaves['Température_2m_Max']

# Diviser les données en ensemble d'entraînement et ensemble de test
features_train, features_test, target_train, target_test = train_test_split(features, target, test_size=0.2, random_state=42)

# 3. Sélection du modèle
model = LinearRegression()

# 4. Entraînement du modèle
model.fit(features_train, target_train)

# Vérifier la performance du modèle sur les données de test
target_pred = model.predict(features_test)
print('RMSE:', np.sqrt(mean_squared_error(target_test, target_pred)))

# 5. Prédiction
future_years = np.array(range(2022, 2031)).reshape(-1, 1)
future_temps = model.predict(future_years)

# Créer un DataFrame avec les années futures et les températures
future_df = pd.DataFrame({'Année': future_years.flatten(), 'Température_2m_Max': future_temps})

# Ajouter le DataFrame futur au DataFrame original
total_df = pd.concat([heatwaves, future_df])

# Tracer les températures réelles et prédites
plt.figure(figsize=(12, 6))
sns.lineplot(x='Année', y='Température_2m_Max', data=total_df,marker="o")
plt.xlabel('Année')
plt.ylabel('Température (°C)')
plt.title('Température Maximale Prédite pour 2022 à 2030')
plt.grid(True)
plt.show()
# Out:
# C:\Users\medth\AppData\Local\Temp\ipykernel_6500\1644964907.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   heatwaves['Année'] = heatwaves['Année'].astype(float)
# d:\Files\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# RMSE: 2.428079695447857

# %% [markdown]
# >Ce graphique suggère que la température maximale devrait atteindre près de 41°C en 2023, puis diminuer à 39°C, avant de progresser lentement jusqu'en 2030.

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# >L'analyse approfondie des données météorologiques de 1983 à 2023 révèle des tendances significatives, où différents facteurs climatiques interagissent pour façonner les résultats observés et prédits par le modèle de machine learning.
#
# - Les températures maximales en hausse sont influencées par divers facteurs, notamment la pression atmosphérique, qui peut affecter la distribution de la chaleur dans l'atmosphère. De plus, la corrélation entre la température et l'humidité relative souligne l'impact des conditions atmosphériques sur les variations de température, où une humidité plus élevée peut contribuer à des températures plus modérées.
#
# - Les phénomènes extrêmes, comme les vagues de chaleur, sont également façonnés par des facteurs multiples, y compris la vitesse et la direction du vent, qui peuvent modifier la perception thermique.
#
# >En outre, l'analyse des données historiques fournit des informations essentielles pour calibrer les modèles de machine learning. Les projections futures, telles que la brusque chute temporaire de la température maximale en 2023, sont le fruit de cette analyse intégrant divers paramètres climatiques.

# %% [markdown]
# >

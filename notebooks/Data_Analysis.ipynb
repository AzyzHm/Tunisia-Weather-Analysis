# %% [markdown]
# # Data Analysis:
# ## Loading the cleaned data:

# %%
import pandas as pd

filepath = "../Data_set/Cleaned_Data.csv"
data = pd.read_csv(filepath)
data.head()
# Out:
#    Year  Month  Day  Temperature_2m  Dew_Point_Temperature_2m  \
# 0  1983      1    1            5.48                     -0.01
# 1  1983      1    2            5.80                      1.58
# 2  1983      1    3            5.43                      3.12
# 3  1983      1    4            7.59                      3.09
# 4  1983      1    5            9.02                      0.41
#
#    Max_Temperature_2m  Min_Temperature_2m  Surface_Temperature  \
# 0               13.02               -0.81                 4.48
# 1               12.84                0.74                 4.75
# 2               11.65                0.27                 4.99
# 3               14.50                2.96                 6.81
# 4               18.82                3.52                 8.19
#
#    Wind_Speed_10m  Wind_Direction_10m  Wind_Speed_50m  Wind_Direction_50m  \
# 0            2.43              263.62            3.73              265.12
# ...
